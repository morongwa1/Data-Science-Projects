# %% [markdown]
# # Applying Principal Component Analysis

# %% [markdown]
# ## Loading data

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.decomposition import PCA


# Load data
df = pd.read_csv('countries.csv')
df.head()
# Out:
#   Country                               Country Groups  BX.KLT.DINV.WD.GD.ZS  \
# 0     CEB               Central Europe and the Baltics              1.555790
# 1     CSS                       Caribbean small states              4.658176
# 2     EAP  East Asia & Pacific (excluding high income)              3.796483
# 3     EAR                   Early-demographic dividend              2.073571
# 4     EAS                          East Asia & Pacific              2.930966
#
#    EG.ELC.ACCS.ZS  EG.FEC.RNEW.ZS  EN.ATM.CO2E.PC  FP.CPI.TOTL.ZG  \
# 0      100.000000       14.538355        6.820042        1.840965
# 1       93.114511        9.096342        9.277109        3.250344
# 2       94.997330       16.471817        5.106045        3.789836
# 3       79.455104       26.481427        2.119827        4.580200
# 4       95.496185       13.729447        5.701783        3.247588
#
#    IT.CEL.SETS.P2  IT.NET.USER.ZS  NE.EXP.GNFS.ZS  ...  NY.GDP.PCAP.CD  \
# 0      122.192106       58.599297       52.333390  ...    12567.128310
# 1      113.628492       35.407690       44.935642  ...     8726.326154
# 2       69.905604       28.957482       30.572597  ...     4007.323783
# 3       68.069446       12.835425       27.711023  ...     2926.483907
# 4       73.657018       34.269800       32.153225  ...     7674.475705
#
#    SP.DYN.AMRT.FE  SP.DYN.AMRT.MA  SP.DYN.CBRT.IN  SP.DYN.CDRT.IN  \
# 0       77.039930      189.578062       10.543330       11.429917
# 1      121.928584      200.568068       17.555646        7.436407
# 2       91.717833      134.835195       14.439063        7.019396
# 3      150.595639      214.978616       22.914627        7.028941
# 4       86.702958      130.465277       13.880915        7.095146
#
#    SP.DYN.IMRT.IN  SP.DYN.LE00.IN  SP.DYN.TFRT.IN  SP.POP.GROW  \
# 0        6.019183       75.295349        1.465325    -0.362710
# 1       18.406085       72.252392        2.151960     0.642147
# 2       19.100000       73.482345        1.843869     0.713160
# 3       40.042149       67.955732        2.763140     1.534541
# 4       18.136433       74.383915        1.797065     0.675231
#
#    SP.URB.TOTL.IN.ZS
# 0          62.059417
# 1          42.083135
# 2          47.696831
# 3          42.113134
# 4          51.791229
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Preprocessing

# %%
# replace variables names to more meaningful ones
df_names = pd.read_html('https://data.cmucreatelab.org/earthtime/WorldBank/')

df_names = df_names[0].set_index('Indicator Code')
df = df.rename(columns={c: df_names.loc[c]['Indicator Name'] for c in df.columns[2:]})

# shorten variable names for plotting
df = df.rename(columns={c: c.split('(')[0] for c in df.columns[2:]})

# drop country column
df = df.drop(columns=['Country'])
df = df.set_index('Country Groups')
df.head()
# Out:
#                                              Foreign direct investment, net inflows   \
# Country Groups
# Central Europe and the Baltics                                              1.555790
# Caribbean small states                                                      4.658176
# East Asia & Pacific (excluding high income)                                 3.796483
# Early-demographic dividend                                                  2.073571
# East Asia & Pacific                                                         2.930966
#
#                                              Access to electricity   \
# Country Groups
# Central Europe and the Baltics                           100.000000
# Caribbean small states                                    93.114511
# East Asia & Pacific (excluding high income)               94.997330
# Early-demographic dividend                                79.455104
# East Asia & Pacific                                       95.496185
#
#                                              Refugee population by country or territory of origin  \
# Country Groups
# Central Europe and the Baltics                                                       14.538355
# Caribbean small states                                                                9.096342
# East Asia & Pacific (excluding high income)                                          16.471817
# Early-demographic dividend                                                           26.481427
# East Asia & Pacific                                                                  13.729447
#
#                                              CO2 emissions   \
# Country Groups
# Central Europe and the Baltics                     6.820042
# Caribbean small states                             9.277109
# East Asia & Pacific (excluding high income)        5.106045
# Early-demographic dividend                         2.119827
# East Asia & Pacific                                5.701783
#
#                                              Inflation, consumer prices   \
# Country Groups
# Central Europe and the Baltics                                  1.840965
# Caribbean small states                                          3.250344
# East Asia & Pacific (excluding high income)                     3.789836
# Early-demographic dividend                                      4.580200
# East Asia & Pacific                                             3.247588
#
#                                              Mobile cellular subscriptions   \
# Country Groups
# Central Europe and the Baltics                                   122.192106
# Caribbean small states                                           113.628492
# East Asia & Pacific (excluding high income)                       69.905604
# Early-demographic dividend                                        68.069446
# East Asia & Pacific                                               73.657018
#
#                                              Individuals using the Internet   \
# Country Groups
# Central Europe and the Baltics                                     58.599297
# Caribbean small states                                             35.407690
# East Asia & Pacific (excluding high income)                        28.957482
# Early-demographic dividend                                         12.835425
# East Asia & Pacific                                                34.269800
#
#                                              Exports of goods and services   \
# Country Groups
# Central Europe and the Baltics                                    52.333390
# Caribbean small states                                            44.935642
# East Asia & Pacific (excluding high income)                       30.572597
# Early-demographic dividend                                        27.711023
# East Asia & Pacific                                               32.153225
#
#                                              Imports of goods and services   \
# Country Groups
# Central Europe and the Baltics                                    53.038989
# Caribbean small states                                            43.747235
# East Asia & Pacific (excluding high income)                       27.095971
# Early-demographic dividend                                        27.370720
# East Asia & Pacific                                               29.112597
#
#                                              GDP per capita   \
# Country Groups
# Central Europe and the Baltics                  12567.128310
# Caribbean small states                           8726.326154
# East Asia & Pacific (excluding high income)      4007.323783
# Early-demographic dividend                       2926.483907
# East Asia & Pacific                              7674.475705
#
#                                              Mortality rate, adult, female   \
# Country Groups
# Central Europe and the Baltics                                    77.039930
# Caribbean small states                                           121.928584
# East Asia & Pacific (excluding high income)                       91.717833
# Early-demographic dividend                                       150.595639
# East Asia & Pacific                                               86.702958
#
#                                              Mortality rate, adult, male   \
# Country Groups
# Central Europe and the Baltics                                 189.578062
# Caribbean small states                                         200.568068
# East Asia & Pacific (excluding high income)                    134.835195
# Early-demographic dividend                                     214.978616
# East Asia & Pacific                                            130.465277
#
#                                              Birth rate, crude   \
# Country Groups
# Central Europe and the Baltics                        10.543330
# Caribbean small states                                17.555646
# East Asia & Pacific (excluding high income)           14.439063
# Early-demographic dividend                            22.914627
# East Asia & Pacific                                   13.880915
#
#                                              Death rate, crude   \
# Country Groups
# Central Europe and the Baltics                        11.429917
# Caribbean small states                                 7.436407
# East Asia & Pacific (excluding high income)            7.019396
# Early-demographic dividend                             7.028941
# East Asia & Pacific                                    7.095146
#
#                                              Mortality rate, infant   \
# Country Groups
# Central Europe and the Baltics                              6.019183
# Caribbean small states                                     18.406085
# East Asia & Pacific (excluding high income)                19.100000
# Early-demographic dividend                                 40.042149
# East Asia & Pacific                                        18.136433
#
#                                              Life expectancy at birth, total   \
# Country Groups
# Central Europe and the Baltics                                      75.295349
# Caribbean small states                                              72.252392
# East Asia & Pacific (excluding high income)                         73.482345
# Early-demographic dividend                                          67.955732
# East Asia & Pacific                                                 74.383915
#
#                                              Fertility rate, total   \
# Country Groups
# Central Europe and the Baltics                             1.465325
# Caribbean small states                                     2.151960
# East Asia & Pacific (excluding high income)                1.843869
# Early-demographic dividend                                 2.763140
# East Asia & Pacific                                        1.797065
#
#                                              Population ages 80 and above, male   \
# Country Groups
# Central Europe and the Baltics                                         -0.362710
# Caribbean small states                                                  0.642147
# East Asia & Pacific (excluding high income)                             0.713160
# Early-demographic dividend                                              1.534541
# East Asia & Pacific                                                     0.675231
#
#                                              Urban land area where elevation is below 5 meters
# Country Groups
# Central Europe and the Baltics                                                       62.059417
# Caribbean small states                                                               42.083135
# East Asia & Pacific (excluding high income)                                          47.696831
# Early-demographic dividend                                                           42.113134
# East Asia & Pacific                                                                  51.791229

# %% [markdown]
# ## Inspect data

# %% [markdown]
# The following plot shows that most of the variables in this dataset are highly positively or negatively correlated with at least one other variable. Examples of correlated variables are the variables measuring the death rate of men, women and infants, and the variables measuring use of cell phones and the internet. This makes the dataset a good candidate for PCA.

# %%
colormap = sns.diverging_palette(220, 10, as_cmap=True)

def corr_heatmap(df):
  # get correlations
  corrs = df.corr()

  # pick appropriate palette for heatmap

  # Plot figsize
  fig, ax = plt.subplots(figsize=(15, 15))

  # to mask mirrored side of heatmap
  dropSelf = np.zeros_like(corrs)
  dropSelf[np.triu_indices_from(dropSelf)] = True

  # Generate Heat Map, with annotations of the correlation strength and 2-decimal floats
  ax = sns.heatmap(corrs, cmap=colormap, annot=True, fmt=".2f", mask=dropSelf, linewidth=2)

  plt.show()

corr_heatmap(df)

# %% [markdown]
# ## Apply PCA

# %%
# drop rows with missing values
df = df.dropna()

# select and standardize features
X = StandardScaler().fit_transform(df.values)

# choose number of components to be generated
nr_comps = 5
pca = PCA(n_components=nr_comps)

# obtain components
principal_components = pca.fit_transform(X)

# transform the components into a pandas data frame
pca_df = pd.DataFrame(principal_components, index=df.index)

# This is to include the country code  as the rownames in the PC's
pca_df.head()
# Out:
#                                                     0         1         2  \
# Country Groups
# Central Europe and the Baltics              -3.924609  3.315577 -0.842078
# Caribbean small states                      -2.260250  2.044123  1.427297
# East Asia & Pacific (excluding high income) -1.787740 -1.080702  1.057935
# Early-demographic dividend                   0.808716 -1.507746  0.643473
# East Asia & Pacific                         -2.287916 -0.782774  0.612767
#
#                                                     3         4
# Country Groups
# Central Europe and the Baltics               2.356141  2.117642
# Caribbean small states                       0.949317  0.775756
# East Asia & Pacific (excluding high income) -0.020315  0.508347
# Early-demographic dividend                   0.165625  0.457137
# East Asia & Pacific                         -0.112555  0.866271

# %% [markdown]
# The Principle components are uncorrelated, showing that PCA has summarised all related information in a smaller number of variables.

# %%
ax = sns.heatmap(pca_df.corr(), cmap=colormap,linewidth=1)
plt.show()

# %% [markdown]
# ### Interpreting PCA

# %% [markdown]
# We can access the correlations between the components and original variables using the components_ method of our PCA() object.

# %%
components = pd.DataFrame(pca.components_, columns=df.columns, index=range(1, nr_comps+1)).transpose()
ax = sns.heatmap(components,cmap=colormap,linewidth=1)
plt.show()

# %% [markdown]
# # Loading Iris dataset

# %%
# loading dataset into a dataframe
iris_df =pd.read_csv('iris.csv')
iris_df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# # Correlation Between features

# %%
# extracte features from the dataframe
X = iris_df.iloc[:,1:5]

X.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0            5.1           3.5            1.4           0.2
# 1            4.9           3.0            1.4           0.2
# 2            4.7           3.2            1.3           0.2
# 3            4.6           3.1            1.5           0.2
# 4            5.0           3.6            1.4           0.2

# %%
# plot the features correlations
colormap = sns.diverging_palette(220, 10, as_cmap=True)

corr_heatmap(X)

# %% [markdown]
# # Data Scaling

# %%
# scaler object
scaler = MinMaxScaler()

# transforming the data
X_scaled = scaler.fit_transform(X.values)

# %% [markdown]
# # Principle Component Analysis (PCA)

# %%
# choose number of components to be generated
nr_comps = 3
pca = PCA(n_components=nr_comps)

# obtain components
principal_components = pca.fit_transform(X_scaled)

# transform the components into a pandas data frame
pca_df = pd.DataFrame(principal_components)

pca_df.head()
# Out:
#           0         1         2
# 0 -0.630361  0.111556 -0.016993
# 1 -0.623546 -0.100313 -0.047120
# 2 -0.669793 -0.047220  0.021648
# 3 -0.654633 -0.098791  0.025214
# 4 -0.648263  0.137558  0.016813

# %%
# plot the transformed version of the data
colormap = sns.diverging_palette(220, 10, as_cmap=True)

corr_heatmap(pca_df)

# %%
sns.heatmap(pca_df.corr(),annot=True, fmt=".2f", linewidth=2);

# %% [markdown]
# The dimensions of the features plot have reduced from 4 to 3. It looks like the petal width or petal length are the redundancy that is likely to have been removed because they showed the highest correlation.
